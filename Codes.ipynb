# %% [markdown]
# # Loading data

# %%
setwd("C:/R") # set the working directory
clean_data <- readRDS(gzcon(url('https://raw.githubusercontent.com/duongkhanhk29/MERITJUST/main/clean_data.RDS')))
dt <-na.omit(clean_data) # remove all missing data
dim(dt)
colnames(dt)
# Out:
# [1] 454  56
#  [1] "stfdem"   "stfeco"   "stfedu"   "stfgov"   "stfhlth"  "blgetmg"
#  [7] "brncntr"  "ctzcntr"  "dscrgrp"  "facntr"   "gndr"     "mocntr"
# [13] "impdiff"  "impenv"   "impfree"  "impfun"   "imprich"  "impsafe"
# [19] "imptrad"  "ipadvnt"  "ipbhprp"  "ipcrtiv"  "ipeqopt"  "ipfrule"
# [25] "ipgdtim"  "iphlppl"  "iplylfr"  "ipmodst"  "iprspot"  "ipshabt"
# [31] "ipstrgv"  "ipsuces"  "ipudrst"  "recexp"   "recgndr"  "recimg"
# [37] "recknow"  "recskil"  "sofrdst"  "sofrpr"   "sofrprv"  "sofrwrk"
# [43] "pplhlp"   "pplfair"  "ppltrst"  "eisced"   "eiscedf"  "eiscedm"
# [49] "eiscedp"  "grsplet"  "hinctnta" "isco08"   "isco08p"  "netilet"
# [55] "occf14b"  "occm14b"

# %% [markdown]
# # Grouping variables

# %%
choose_vars <- read.csv("https://raw.githubusercontent.com/duongkhanhk29/MERITJUST/main/choose_vars.csv")
print(choose_vars[,1:2])
# Out:
#         Var                  Topic
# 1    stfdem Government performance
# 2    stfeco Government performance
# 3    stfedu Government performance
# 4    stfgov Government performance
# 5   stfhlth Government performance
# 6   blgetmg         Discrimination
# 7   brncntr         Discrimination
# 8   ctzcntr         Discrimination
# 9   dscrgrp         Discrimination
# 10   facntr         Discrimination
# 11     gndr         Discrimination
# 12   mocntr         Discrimination
# 13  impdiff           Human Values
# 14   impenv           Human Values
# 15  impfree           Human Values
# 16   impfun           Human Values
# 17  imprich           Human Values
# 18  impsafe           Human Values
# 19  imptrad           Human Values
# 20  ipadvnt           Human Values
# 21  ipbhprp           Human Values
# 22  ipcrtiv           Human Values
# 23  ipeqopt           Human Values
# 24  ipfrule           Human Values
# 25  ipgdtim           Human Values
# 26  iphlppl           Human Values
# 27  iplylfr           Human Values
# 28  ipmodst           Human Values
# 29  iprspot           Human Values
# 30  ipshabt           Human Values
# 31  ipstrgv           Human Values
# 32  ipsuces           Human Values
# 33  ipudrst           Human Values
# 34   recexp Opportunity Inequality
# 35  recgndr Opportunity Inequality
# 36   recimg Opportunity Inequality
# 37  recknow Opportunity Inequality
# 38  recskil Opportunity Inequality
# 39  sofrdst        Social Fairness
# 40   sofrpr        Social Fairness
# 41  sofrprv        Social Fairness
# 42  sofrwrk        Social Fairness
# 43   pplhlp           Social Trust
# 44  pplfair           Social Trust
# 45  ppltrst           Social Trust
# 46   eisced   Socioeconomic Status
# 47  eiscedf   Socioeconomic Status
# 48  eiscedm   Socioeconomic Status
# 49  eiscedp   Socioeconomic Status
# 50  grsplet   Socioeconomic Status
# 51 hinctnta   Socioeconomic Status
# 52   isco08   Socioeconomic Status
# 53  isco08p   Socioeconomic Status
# 54  netilet   Socioeconomic Status
# 55  occf14b   Socioeconomic Status
# 56  occm14b   Socioeconomic Status

# %% [markdown]
# # Unfolding data

# %%
library(smacof)
unfold <- unfolding(dt, type = "ordinal", conditionality = "row")
dt_adj <- setNames(as.data.frame(unfold[["confdist"]]), colnames(dt))
dim(dt_adj)
colnames(dt_adj)
# Out:
# [1] 454  56
#  [1] "stfdem"   "stfeco"   "stfedu"   "stfgov"   "stfhlth"  "blgetmg"
#  [7] "brncntr"  "ctzcntr"  "dscrgrp"  "facntr"   "gndr"     "mocntr"
# [13] "impdiff"  "impenv"   "impfree"  "impfun"   "imprich"  "impsafe"
# [19] "imptrad"  "ipadvnt"  "ipbhprp"  "ipcrtiv"  "ipeqopt"  "ipfrule"
# [25] "ipgdtim"  "iphlppl"  "iplylfr"  "ipmodst"  "iprspot"  "ipshabt"
# [31] "ipstrgv"  "ipsuces"  "ipudrst"  "recexp"   "recgndr"  "recimg"
# [37] "recknow"  "recskil"  "sofrdst"  "sofrpr"   "sofrprv"  "sofrwrk"
# [43] "pplhlp"   "pplfair"  "ppltrst"  "eisced"   "eiscedf"  "eiscedm"
# [49] "eiscedp"  "grsplet"  "hinctnta" "isco08"   "isco08p"  "netilet"
# [55] "occf14b"  "occm14b"

# %% [markdown]
# # Two-dimensional scaling

# %%
mds<-as.data.frame(unfold[["conf.col"]]) # extract features
print(mds)
# Out:
#                   D1         D2
# stfdem   -1.22508528  0.8336637
# stfeco   -1.22147270  0.9797447
# stfedu   -1.40467051  0.7501296
# stfgov   -1.03541452  0.7663015
# stfhlth  -1.24742471  0.8242788
# blgetmg  -0.02943878  0.1352590
# brncntr  -0.03212067  0.1426970
# ctzcntr  -0.03149446  0.1403921
# dscrgrp  -0.03135645  0.1375407
# facntr   -0.02892768  0.1450706
# gndr     -0.05416359  0.1100483
# mocntr   -0.03040352  0.1439262
# impdiff  -0.14894219 -0.6346544
# impenv   -0.05235007 -0.3752518
# impfree  -0.15955869 -0.3890392
# impfun   -0.01382398 -0.6527621
# imprich  -0.28209994 -0.8886047
# impsafe  -0.17511617 -0.4717179
# imptrad  -0.03838432 -0.5874444
# ipadvnt  -0.16442947 -0.8333030
# ipbhprp  -0.13608609 -0.5477911
# ipcrtiv  -0.11915632 -0.5131443
# ipeqopt  -0.06182174 -0.4320552
# ipfrule  -0.24527446 -0.7361632
# ipgdtim  -0.02310430 -0.5685883
# iphlppl  -0.10660432 -0.4103432
# iplylfr  -0.03597260 -0.3262388
# ipmodst  -0.01280985 -0.5876819
# iprspot  -0.17588751 -0.6821298
# ipshabt  -0.20101511 -0.6588317
# ipstrgv  -0.10099916 -0.4806930
# ipsuces  -0.29351125 -0.5971723
# ipudrst  -0.02854709 -0.4666090
# recexp   -0.15863684 -0.6633798
# recgndr  -0.09320065 -0.3615555
# recimg   -0.20219185 -0.3647390
# recknow  -0.02420169 -0.5796064
# recskil  -0.15596171 -0.6697266
# sofrdst   0.10838602 -0.5828646
# sofrpr   -0.01227968 -0.4237239
# sofrprv  -0.14148269 -0.8290301
# sofrwrk  -0.14873275 -0.3530507
# pplhlp   -1.06674127  0.9110249
# pplfair  -1.03490249  1.2859177
# ppltrst  -1.07992971  1.0059748
# eisced    1.14968193  0.7323633
# eiscedf   0.82090672  0.5573090
# eiscedm   0.83777250  0.4928520
# eiscedp   1.21970385  0.4600061
# grsplet   1.26097047  0.7246198
# hinctnta  1.80225460  0.9276625
# isco08    1.18094178  1.2797720
# isco08p   1.13904356  1.1812800
# netilet   1.25957511  0.6492120
# occf14b   1.04301953  0.7272748
# occm14b   1.24347276  0.6235746

# %% [markdown]
# # Correlation network

# %%
library("RColorBrewer")
Topic_colors <- brewer.pal("Set2",n = length(unique(choose_vars$Topic))) # set colors for topics
library(qgraph) # Plot correlation network
qgraph(abs(cor(dt_adj)), node.width=0.7, labels = F, # correlatin size with absolute
       groups=choose_vars$Topic, layout="spring",
       color = Topic_colors, legend=F, repulsion=0.6,threshold = 0.5) # omit correlation <0.5
# Out:
# plot without title

# %% [markdown]
# # Clustering analysis

# %%
library(ggplot2)
library(factoextra)
km <- eclust(mds, "kmeans", nboot = 1000, graph = F) # K-means clustering
hc <- eclust(mds, "hclust", nboot = 1000, graph = F) # Hierarchical clustering (HC)
mds$Topic<-choose_vars$Topic # my clustering
mds$Kmeans<-factor(km$cluster) # clustered by K-means
mds$Hierarchy<-factor(hc$cluster) # clustered by HC
print(mds)
# Out:
# Welcome! Want to learn more? See two factoextra-related books at https://goo.gl/ve3WBa
#                   D1         D2                  Topic Kmeans Hierarchy
# stfdem   -1.22508528  0.8336637 Government performance      2         1
# stfeco   -1.22147270  0.9797447 Government performance      2         1
# stfedu   -1.40467051  0.7501296 Government performance      2         1
# stfgov   -1.03541452  0.7663015 Government performance      2         1
# stfhlth  -1.24742471  0.8242788 Government performance      2         1
# blgetmg  -0.02943878  0.1352590         Discrimination      1         2
# brncntr  -0.03212067  0.1426970         Discrimination      1         2
# ctzcntr  -0.03149446  0.1403921         Discrimination      1         2
# dscrgrp  -0.03135645  0.1375407         Discrimination      1         2
# facntr   -0.02892768  0.1450706         Discrimination      1         2
# gndr     -0.05416359  0.1100483         Discrimination      1         2
# mocntr   -0.03040352  0.1439262         Discrimination      1         2
# impdiff  -0.14894219 -0.6346544           Human Values      1         3
# impenv   -0.05235007 -0.3752518           Human Values      1         3
# impfree  -0.15955869 -0.3890392           Human Values      1         3
# impfun   -0.01382398 -0.6527621           Human Values      1         3
# imprich  -0.28209994 -0.8886047           Human Values      1         3
# impsafe  -0.17511617 -0.4717179           Human Values      1         3
# imptrad  -0.03838432 -0.5874444           Human Values      1         3
# ipadvnt  -0.16442947 -0.8333030           Human Values      1         3
# ipbhprp  -0.13608609 -0.5477911           Human Values      1         3
# ipcrtiv  -0.11915632 -0.5131443           Human Values      1         3
# ipeqopt  -0.06182174 -0.4320552           Human Values      1         3
# ipfrule  -0.24527446 -0.7361632           Human Values      1         3
# ipgdtim  -0.02310430 -0.5685883           Human Values      1         3
# iphlppl  -0.10660432 -0.4103432           Human Values      1         3
# iplylfr  -0.03597260 -0.3262388           Human Values      1         3
# ipmodst  -0.01280985 -0.5876819           Human Values      1         3
# iprspot  -0.17588751 -0.6821298           Human Values      1         3
# ipshabt  -0.20101511 -0.6588317           Human Values      1         3
# ipstrgv  -0.10099916 -0.4806930           Human Values      1         3
# ipsuces  -0.29351125 -0.5971723           Human Values      1         3
# ipudrst  -0.02854709 -0.4666090           Human Values      1         3
# recexp   -0.15863684 -0.6633798 Opportunity Inequality      1         3
# recgndr  -0.09320065 -0.3615555 Opportunity Inequality      1         3
# recimg   -0.20219185 -0.3647390 Opportunity Inequality      1         3
# recknow  -0.02420169 -0.5796064 Opportunity Inequality      1         3
# recskil  -0.15596171 -0.6697266 Opportunity Inequality      1         3
# sofrdst   0.10838602 -0.5828646        Social Fairness      1         3
# sofrpr   -0.01227968 -0.4237239        Social Fairness      1         3
# sofrprv  -0.14148269 -0.8290301        Social Fairness      1         3
# sofrwrk  -0.14873275 -0.3530507        Social Fairness      1         3
# pplhlp   -1.06674127  0.9110249           Social Trust      2         1
# pplfair  -1.03490249  1.2859177           Social Trust      2         1
# ppltrst  -1.07992971  1.0059748           Social Trust      2         1
# eisced    1.14968193  0.7323633   Socioeconomic Status      3         4
# eiscedf   0.82090672  0.5573090   Socioeconomic Status      3         4
# eiscedm   0.83777250  0.4928520   Socioeconomic Status      3         4
# eiscedp   1.21970385  0.4600061   Socioeconomic Status      3         4
# grsplet   1.26097047  0.7246198   Socioeconomic Status      3         4
# hinctnta  1.80225460  0.9276625   Socioeconomic Status      3         4
# isco08    1.18094178  1.2797720   Socioeconomic Status      3         4
# isco08p   1.13904356  1.1812800   Socioeconomic Status      3         4
# netilet   1.25957511  0.6492120   Socioeconomic Status      3         4
# occf14b   1.04301953  0.7272748   Socioeconomic Status      3         4
# occm14b   1.24347276  0.6235746   Socioeconomic Status      3         4

# %% [markdown]
# # Visualizing clusters

# %%
library(ggforce)
mdsplot<- ggplot(mds, aes(D1, D2)) + theme_classic() +
          geom_point(aes(color = Topic), size = 4)+
          scale_color_manual(values=Topic_colors)
mdsplot+geom_mark_ellipse(aes(linetype=Kmeans,label=Kmeans),show.legend=F) # with K-means techniques
mdsplot+geom_mark_ellipse(aes(linetype=Hierarchy,label=Hierarchy),show.legend=F) # with hierarchical clustering
# Out:
# plot without title
# plot without title

# %% [markdown]
# # Unidimensional scaling

# %%
unidimension <- function(data, topic) {
  subset_data <- data[, choose_vars$Var[choose_vars$Topic == topic]]
  dts <- dist(t(subset_data))
  mds <- round(sort(uniscale(dts)$conf),3);
  return(mds)
}
unidimension(dt_adj,"Opportunity Inequality")
unidimension(dt_adj,"Social Fairness")
# Out:
# Permutation 120 of 120
# recskil  recexp recknow  recimg recgndr
#  -0.663  -0.636  -0.190   0.671   0.818
# Permutation 24 of 24
# sofrprv sofrdst  sofrpr sofrwrk
#  -0.938  -0.135   0.422   0.650

# %% [markdown]
# # Double machine learning

# %%
library(ranger)
library(data.table)
library(mlr3)
library(mlr3learners)
library(DoubleML)
fit_dml_plr <- function(data, y, d) {
  data = as.data.table(data)
  colnames(data) <- make.names(colnames(data))
  x = setdiff(colnames(data), c(y, d))
  dml_data = DoubleMLData$new(data, y_col = y, d_cols = d, x_cols = x)
  ## Initialization of the Causal PLR Model
  set.seed(31415) # required to replicate sample split
  learner_g = lrn("regr.ranger", num.trees = 500, min.node.size = 2, max.depth = 5)
  learner_m = lrn("regr.ranger", num.trees = 500, min.node.size = 2, max.depth = 5)
  dml_plr = DoubleMLPLR$new(dml_data,ml_m = learner_m, ml_l = learner_g,
                            score = "partialling out", n_folds = 5, n_rep = 1)
  dml_plr$fit(); summary = dml_plr$summary()
}

est_tab <- function(data, x) {
  result_x <- as.data.frame(rbind(
    fit_dml_plr(data, "sofrdst", x),
    fit_dml_plr(data, "sofrpr", x),
    fit_dml_plr(data, "sofrprv", x),
    fit_dml_plr(data, "sofrwrk", x)
  ))
  colnames(result_x) <- c("estimate", "std_error", "t_value", "p_value")
  result_x$model <- c("sofrdst", "sofrpr", "sofrprv", "sofrwrk")
  result_x$var <- x
    return(result_x)
}

merit <- rbind(est_tab(dt_adj,"recskil"),
               est_tab(dt_adj,"recexp"),
               est_tab(dt_adj,"recgndr"),
               est_tab(dt_adj,"recimg"),
               est_tab(dt_adj,"recknow"))
# Out:
# INFO  [14:46:07.860] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:08.042] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:08.198] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:08.358] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:08.503] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:08.796] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:08.948] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:09.093] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:09.229] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:09.369] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recskil    0.6467     0.2845   2.273    0.023 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:09.783] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:09.922] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:10.064] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:10.204] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:10.343] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:10.644] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:10.828] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:10.963] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:11.105] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:11.240] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recskil    0.4141     0.2655    1.56    0.119
#
#
# INFO  [14:46:11.648] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:11.829] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:11.969] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:12.112] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:12.248] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:12.564] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:12.743] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:12.883] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:13.019] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:13.159] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recskil   1.15751    0.08466   13.67   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:13.619] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:13.762] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:13.899] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:14.040] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:14.175] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:14.477] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:14.648] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:14.787] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:14.929] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:15.077] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recskil    0.4702     0.2080    2.26   0.0238 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:15.608] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:15.745] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:15.885] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:16.034] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:16.171] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:16.449] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:16.626] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:16.779] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:16.922] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:17.062] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#        Estimate. Std. Error t value Pr(>|t|)
# recexp    0.5891     0.3012   1.956   0.0505 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:17.486] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:17.623] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:17.797] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:17.934] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:18.073] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:18.373] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:18.563] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:18.722] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:18.897] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:19.069] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#        Estimate. Std. Error t value Pr(>|t|)
# recexp    0.3980     0.2732   1.457    0.145
#
#
# INFO  [14:46:19.572] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:19.731] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:19.915] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:20.071] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:20.219] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:20.545] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:20.691] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:20.842] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:20.978] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:21.120] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#        Estimate. Std. Error t value Pr(>|t|)
# recexp   1.10265    0.07541   14.62   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:21.545] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:21.689] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:21.826] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:21.971] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:22.110] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:22.416] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:22.554] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:22.695] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:22.836] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:22.975] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#        Estimate. Std. Error t value Pr(>|t|)
# recexp    0.5343     0.1780   3.002  0.00268 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:23.627] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:23.763] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:23.903] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:24.047] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:24.186] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:24.471] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:24.609] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:24.785] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:24.925] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:25.069] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recgndr  -0.03924    0.29486  -0.133    0.894
#
#
# INFO  [14:46:25.470] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:25.646] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:25.782] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:25.927] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:26.066] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:26.357] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:26.491] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:26.627] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:26.766] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:26.906] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recgndr     0.472      0.135   3.496 0.000473 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:27.303] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:27.550] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:27.758] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:27.970] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:28.143] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:28.514] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:28.663] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:28.860] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:29.060] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:29.254] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recgndr   -0.1111     0.2565  -0.433    0.665
#
#
# INFO  [14:46:29.744] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:29.933] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:30.070] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:30.214] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:30.420] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:30.761] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:30.918] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:31.060] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:31.243] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:31.383] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recgndr   0.91066    0.03204   28.43   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:31.792] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:31.986] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:32.124] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:32.260] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:32.397] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:32.678] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:32.813] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:32.965] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:33.107] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:33.246] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#        Estimate. Std. Error t value Pr(>|t|)
# recimg   -0.7583     0.2465  -3.077  0.00209 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:33.698] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:33.837] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:33.980] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:34.132] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:34.272] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:34.556] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:34.691] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:34.830] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:34.973] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:35.154] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#        Estimate. Std. Error t value Pr(>|t|)
# recimg   -0.1574     0.1538  -1.023    0.306
#
#
# INFO  [14:46:35.578] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:35.711] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:35.851] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:35.995] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:36.131] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:36.416] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:36.557] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:36.697] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:36.875] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:37.014] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#        Estimate. Std. Error t value Pr(>|t|)
# recimg   -0.1464     0.1714  -0.854    0.393
#
#
# INFO  [14:46:37.465] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:37.599] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:37.738] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:37.875] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:38.016] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:38.321] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:38.457] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:38.595] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:38.732] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:38.873] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#        Estimate. Std. Error t value Pr(>|t|)
# recimg   0.80065    0.03807   21.03   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:39.298] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:39.438] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:39.573] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:39.743] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:39.880] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:40.187] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:40.321] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:40.456] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:40.594] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:40.732] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recknow    1.5076     0.1366   11.04   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:41.228] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:41.387] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:41.535] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:41.708] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:41.845] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:42.152] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:42.320] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:42.458] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:42.596] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:42.735] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recknow   0.86785    0.04499   19.29   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:43.215] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:43.359] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:43.493] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:43.629] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:43.772] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:44.104] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:44.248] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:44.391] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:44.536] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:44.703] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recknow   0.90487    0.06781   13.34   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
#
# INFO  [14:46:45.126] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 1/5)
# INFO  [14:46:45.265] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 2/5)
# INFO  [14:46:45.404] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 3/5)
# INFO  [14:46:45.543] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 4/5)
# INFO  [14:46:45.678] [mlr3] Applying learner 'regr.ranger' on task 'nuis_l' (iter 5/5)
# INFO  [14:46:45.989] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 1/5)
# INFO  [14:46:46.164] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 2/5)
# INFO  [14:46:46.301] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 3/5)
# INFO  [14:46:46.471] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 4/5)
# INFO  [14:46:46.609] [mlr3] Applying learner 'regr.ranger' on task 'nuis_m' (iter 5/5)
# Estimates and significance testing of the effect of target variables
#         Estimate. Std. Error t value Pr(>|t|)
# recknow   -0.1289     0.3441  -0.374    0.708

# %% [markdown]
# # Printing Double machine learning output

# %%
print(merit,row.names = FALSE)
# Out:
#     estimate  std_error    t_value       p_value   model     var
#   0.64672159 0.28452869  2.2729574  2.302875e-02 sofrdst recskil
#   0.41414365 0.26552527  1.5597147  1.188273e-01  sofrpr recskil
#   1.15750650 0.08465873 13.6726177  1.479745e-42 sofrprv recskil
#   0.47016473 0.20800862  2.2603137  2.380179e-02 sofrwrk recskil
#   0.58911838 0.30123138  1.9557006  5.050044e-02 sofrdst  recexp
#   0.39801077 0.27322311  1.4567244  1.451925e-01  sofrpr  recexp
#   1.10264555 0.07540514 14.6229493  2.005223e-48 sofrprv  recexp
#   0.53431136 0.17798319  3.0020326  2.681834e-03 sofrwrk  recexp
#  -0.03923815 0.29486450 -0.1330718  8.941366e-01 sofrdst recgndr
#   0.47202432 0.13503647  3.4955321  4.731176e-04  sofrpr recgndr
#  -0.11114358 0.25651586 -0.4332815  6.648103e-01 sofrprv recgndr
#   0.91065989 0.03203778 28.4245671 1.005288e-177 sofrwrk recgndr
#  -0.75834926 0.24649032 -3.0765883  2.093842e-03 sofrdst  recimg
#  -0.15738978 0.15379581 -1.0233685  3.061337e-01  sofrpr  recimg
#  -0.14641783 0.17143683 -0.8540629  3.930701e-01 sofrprv  recimg
#   0.80064707 0.03807155 21.0300603  3.482071e-98 sofrwrk  recimg
#   1.50762094 0.13658282 11.0381451  2.501435e-28 sofrdst recknow
#   0.86784503 0.04499352 19.2882248  6.744980e-83  sofrpr recknow
#   0.90487174 0.06781248 13.3437341  1.288407e-40 sofrprv recknow
#  -0.12886824 0.34413962 -0.3744650  7.080584e-01 sofrwrk recknow

# %% [markdown]
# # Plotting Double machine learning output

# %%
plot_results <- function(dt) {
  results = dt
  # calculate the lower and upper bounds of the 95% confidence intervals
  results$conf_low <- results$estimate - 1.96*results$std_error
  results$conf_high <- results$estimate + 1.96*results$std_error
  # create a factor variable for the p-value significance levels
  results$p_value_level <- cut(
    results$p_value,
    breaks = c(-Inf, 0.01, 0.05, 0.1, Inf),
    labels = c("*** (p < 0.01)", "** (p < 0.05)", "* (p < 0.1)", " (p >= 0.1)")
  )
  # plot the estimates with error bars and size the points according to the p-value levels
  ggplot(results, aes(x = var, y = estimate)) +
    geom_pointrange(aes(ymin = conf_low, ymax = conf_high), color = "darkblue") +
    geom_point(aes(size = p_value_level)) +
    geom_text(aes(label = sprintf("%.3f", estimate)), nudge_x = 0.3, size=3) +
    scale_x_discrete("") + geom_hline(yintercept = 0, color = "red") +
    theme_bw() + ylab(NULL) + 
    scale_size_discrete(name = "p-value",limits = rev(levels(results$p_value_level))) +
    coord_flip() + facet_grid(~model)
}
plot_results(merit)
# Out:
# Warning message:
# "Using size for a discrete variable is not advised."
# plot without title
